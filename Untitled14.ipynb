# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
gymdata=pd.read_csv("D:\\PGP-AIML\\CardioGoodFitness.csv")

# %%
gymdata.head()
# Out:
#   Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  Miles
# 0   TM195   18    Male         14        Single      3        4   29562    112
# 1   TM195   19    Male         15        Single      2        3   31836     75
# 2   TM195   19  Female         14     Partnered      4        3   30699     66
# 3   TM195   19    Male         12        Single      3        3   32973     85
# 4   TM195   20    Male         13     Partnered      4        2   35247     47

# %%
gymdata
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# 5     TM195   20  Female         14     Partnered      3        3   32973
# 6     TM195   21  Female         14     Partnered      3        3   35247
# 7     TM195   21    Male         13        Single      3        3   32973
# 8     TM195   21    Male         15        Single      5        4   35247
# 9     TM195   21  Female         15     Partnered      2        3   37521
# 10    TM195   22    Male         14        Single      3        3   36384
# 11    TM195   22  Female         14     Partnered      3        2   35247
# ...

# %%
gymdata.isna()
# Out:
#      Product    Age  Gender  Education  MaritalStatus  Usage  Fitness  Income  \
# 0      False  False   False      False          False  False    False   False
# 1      False  False   False      False          False  False    False   False
# 2      False  False   False      False          False  False    False   False
# 3      False  False   False      False          False  False    False   False
# 4      False  False   False      False          False  False    False   False
# 5      False  False   False      False          False  False    False   False
# 6      False  False   False      False          False  False    False   False
# 7      False  False   False      False          False  False    False   False
# 8      False  False   False      False          False  False    False   False
# 9      False  False   False      False          False  False    False   False
# 10     False  False   False      False          False  False    False   False
# ...

# %%
gymdata[gymdata.isna()==True].count()
# Out:
# Product          0
# Age              0
# Gender           0
# Education        0
# MaritalStatus    0
# Usage            0
# Fitness          0
# Income           0
# Miles            0
# dtype: int64

# %%
gymdata['Age'].mean()
# Out:
# 28.788888888888888

# %%
gymdata['Income'].mean()
# Out:
# 53719.57777777778

# %%
gymdata['Income'].std()
# Out:
# 16506.68422623862

# %%
gymdata['Income'].median()
# Out:
# 50596.5

# %%
gymdata['Income'].count()
# Out:
# 0    45480
# dtype: int64

# %%
gymdata
# Out:
#     Product  Age  Gender  Education MaritalStatus  Usage  Fitness  Income  \
# 0     TM195   18    Male         14        Single      3        4   29562
# 1     TM195   19    Male         15        Single      2        3   31836
# 2     TM195   19  Female         14     Partnered      4        3   30699
# 3     TM195   19    Male         12        Single      3        3   32973
# 4     TM195   20    Male         13     Partnered      4        2   35247
# 5     TM195   20  Female         14     Partnered      3        3   32973
# 6     TM195   21  Female         14     Partnered      3        3   35247
# 7     TM195   21    Male         13        Single      3        3   32973
# 8     TM195   21    Male         15        Single      5        4   35247
# 9     TM195   21  Female         15     Partnered      2        3   37521
# 10    TM195   22    Male         14        Single      3        3   36384
# 11    TM195   22  Female         14     Partnered      3        2   35247
# ...

# %%
plt.hist(gymdata['Income'])
# Out:
# (array([23., 26., 48., 41., 15.,  5.,  3.,  5., 10.,  4.]),
#  array([ 29562. ,  37063.9,  44565.8,  52067.7,  59569.6,  67071.5,
#          74573.4,  82075.3,  89577.2,  97079.1, 104581. ]),
#  <a list of 10 Patch objects>)

# %%
sns.hist(gymdata['Income'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-30-d5f53b9c7bb5> in <module>
# ----> 1 sns.hist(gymdata['Income'])
#
# AttributeError: module 'seaborn' has no attribute 'hist'

# %%
sns.boxplot(gymdata['Income'])

# %%
sns.boxplot(x='Gender',y='Income',data=gymdata)

# %%
pd.crosstab(gymdata['Gender'],gymdata['Product'])
# Out:
# Product  TM195  TM498  TM798
# Gender
# Female      40     29      7
# Male        40     31     33

# %%
sns.countplot(x='Gender',hue='Product',data=gymdata)

# %%
pd.pivot_table(gymdata,'Income',index=['Education','Gender'], columns=['Product','Age'])
# Out:
# Product             TM195                                                \
# Age                    18       19       20       21       22        23
# Education Gender
# 12        Male        NaN  32973.0      NaN      NaN      NaN       NaN
# 13        Female      NaN      NaN      NaN      NaN      NaN       NaN
#           Male        NaN      NaN  35247.0  32973.0      NaN       NaN
# 14        Female      NaN  30699.0  32973.0  35247.0  35247.0  34110.00
#           Male    29562.0      NaN      NaN      NaN  36384.0  38658.00
# 15        Female      NaN      NaN      NaN  37521.0      NaN  34110.00
#           Male        NaN  31836.0      NaN  35247.0      NaN       NaN
# 16        Female      NaN      NaN      NaN      NaN  36384.0  38658.00
#           Male        NaN      NaN      NaN      NaN      NaN  40079.25
# 18        Female      NaN      NaN      NaN      NaN      NaN       NaN
#           Male        NaN      NaN      NaN      NaN      NaN       NaN
# ...

# %%
sns.pairplot(gymdata)

# %%
sns.pairplot(gymdata[['Miles','Income','Age']])

# %%
gymdata.hist('Income')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023CA38303C8>]],
#       dtype=object)

# %%
sns.distplot(gymdata['Income'])

# %%
gymdata.hist(by='Product',column='Income')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000023CA49577B8>,
# ...
#       dtype=object)

# %%
gymdata.corr()
# Out:
#                 Age  Education     Usage   Fitness    Income     Miles
# Age        1.000000   0.280496  0.015064  0.061105  0.513414  0.036618
# Education  0.280496   1.000000  0.395155  0.410581  0.625827  0.307284
# Usage      0.015064   0.395155  1.000000  0.668606  0.519537  0.759130
# Fitness    0.061105   0.410581  0.668606  1.000000  0.535005  0.785702
# Income     0.513414   0.625827  0.519537  0.535005  1.000000  0.543473
# Miles      0.036618   0.307284  0.759130  0.785702  0.543473  1.000000

# %%
sns.heatmap(gymdata.corr())
