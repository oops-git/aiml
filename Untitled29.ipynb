# %%
# this program is for Naive Bayes
# let's import the usual suspects
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pima=pd.read_csv("D:\PGP-AIML\Supervised Learning\Classification Models - Naive Bayes and KNN\pima-indians-diabetes-2.csv")

# %%
pima.describe()
# Out:
#              Preg        Plas        Pres        skin        test        mass  \
# count  768.000000  768.000000  768.000000  768.000000  768.000000  768.000000
# mean     3.845052  120.894531   69.105469   20.536458   79.799479   31.992578
# std      3.369578   31.972618   19.355807   15.952218  115.244002    7.884160
# min      0.000000    0.000000    0.000000    0.000000    0.000000    0.000000
# 25%      1.000000   99.000000   62.000000    0.000000    0.000000   27.300000
# 50%      3.000000  117.000000   72.000000   23.000000   30.500000   32.000000
# 75%      6.000000  140.250000   80.000000   32.000000  127.250000   36.600000
# max     17.000000  199.000000  122.000000   99.000000  846.000000   67.100000
#
#              pedi         age       class
# count  768.000000  768.000000  768.000000
# mean     0.471876   33.240885    0.348958
# std      0.331329   11.760232    0.476951
# min      0.078000   21.000000    0.000000
# 25%      0.243750   24.000000    0.000000
# ...

# %%
pima.head()
# Out:
#    Preg  Plas  Pres  skin  test  mass   pedi  age  class
# 0     6   148    72    35     0  33.6  0.627   50      1
# 1     1    85    66    29     0  26.6  0.351   31      0
# 2     8   183    64     0     0  23.3  0.672   32      1
# 3     1    89    66    23    94  28.1  0.167   21      0
# 4     0   137    40    35   168  43.1  2.288   33      1

# %%
print(pima.isnull().values.any())
# Out:
# False

# %%
pima.shape
# Out:
# (768, 9)

# %%
columns=list(pima[0:-1])

# %%
columns
# Out:
# ['Preg', 'Plas', 'Pres', 'skin', 'test', 'mass', 'pedi', 'age', 'class']

# %%
pima[columns].hist(stacked=False,bins=100, figsize=(12,30), layout=(14,2))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001A362E2DA58>,
# ...
#       dtype=object)

# %%
pima.corr()
# Out:
#            Preg      Plas      Pres      skin      test      mass      pedi  \
# Preg   1.000000  0.129459  0.141282 -0.081672 -0.073535  0.017683 -0.033523
# Plas   0.129459  1.000000  0.152590  0.057328  0.331357  0.221071  0.137337
# Pres   0.141282  0.152590  1.000000  0.207371  0.088933  0.281805  0.041265
# skin  -0.081672  0.057328  0.207371  1.000000  0.436783  0.392573  0.183928
# test  -0.073535  0.331357  0.088933  0.436783  1.000000  0.197859  0.185071
# mass   0.017683  0.221071  0.281805  0.392573  0.197859  1.000000  0.140647
# pedi  -0.033523  0.137337  0.041265  0.183928  0.185071  0.140647  1.000000
# age    0.544341  0.263514  0.239528 -0.113970 -0.042163  0.036242  0.033561
# class  0.221898  0.466581  0.065068  0.074752  0.130548  0.292695  0.173844
#
#             age     class
# Preg   0.544341  0.221898
# Plas   0.263514  0.466581
# Pres   0.239528  0.065068
# skin  -0.113970  0.074752
# test  -0.042163  0.130548
# mass   0.036242  0.292695
# ...

# %%
def plot_corr(df, size=11):
    corr = df.corr()
    fig, ax = plt.subplots(figsize=(size, size))
    ax.matshow(corr)
    plt.xticks(range(len(corr.columns)), corr.columns)
    plt.yticks(range(len(corr.columns)), corr.columns)

# %%
plot_corr(pima)

# %%
sns.pairplot(pima)

# %%
pima.dtypes
# Out:
# Preg       int64
# Plas       int64
# Pres       int64
# skin       int64
# test       int64
# mass     float64
# pedi     float64
# age        int64
# class      int64
# dtype: object

# %%
n_true=len(pima[pima['class']==1])
n_false=len(pima[pima['class']==0])

# %%
X=pima.drop('class',axis=1)

# %%
y=pima[['class']]

# %%
print(n_true*100/len(pima), n_false*100/len(pima))
# Out:
# 34.895833333333336 65.10416666666667

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
# 1 is just any random seed number

X_train.head()
# Out:
#      Preg  Plas  Pres  skin  test  mass   pedi  age
# 88     15   136    70    32   110  37.1  0.153   43
# 467     0    97    64    36   100  36.8  0.600   25
# 550     1   116    70    28     0  27.4  0.204   21
# 147     2   106    64    35   119  30.5  1.400   34
# 481     0   123    88    37     0  35.2  0.197   29

# %%
len(X_train)
# Out:
# 537

# %%
len (X_test)
# Out:
# 231

# %%
len (y_train)
# Out:
# 537

# %%
len (y_test)
# Out:
# 231

# %%
len(X_train)*100/(len(X_train)+len(X_test))
# Out:
# 69.921875

# %%
len(X_test)*100/(len(X_train)+len(X_test))
# Out:
# 30.078125

# %%
print (n_true, n_false)
# Out:
# 268 500

# %%
train_true=len(y_train[y_train['class']==1])
train_false=len(y_train[y_train['class']==0])
test_true=len(y_test[y_test['class']==1])
test_false=len(y_test[y_test['class']==0])

# %%
print (train_true, train_false, test_true, test_false)
# Out:
# 183 354 85 146
